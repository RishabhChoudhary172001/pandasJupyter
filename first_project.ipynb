# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'C:\\Users\\HP\\Downloads\\temp.csv'
df = pd.read_csv(file_path, encoding='latin-1')
print(df.head(3))
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0   Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2   Marcus Dunlap     Regular Air      Home Office        Furniture  ...
#
#   Region State or Province         City  Postal Code  Order Date   Ship Date  \
# 0   West        Washington    Anacortes        98221  07-01-2015  08-01-2015
# 1   West        California  San Gabriel        91776  13-06-2015  15-06-2015
# 2   East        New Jersey      Roselle         7203  15-02-2015  17-02-2015
#
#       Profit Quantity ordered new    Sales Order ID
# ...

# %%
df.shape
# Out:
# (1952, 25)

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 16

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Row ID                  0.000000
# Order Priority          0.000000
# Discount                0.000000
# Unit Price              0.000000
# Shipping Cost           0.000000
# Customer ID             0.000000
# Customer Name           0.000000
# Ship Mode               0.000000
# Customer Segment        0.000000
# Product Category        0.000000
# Product Sub-Category    0.000000
# Product Container       0.000000
# Product Name            0.000000
# Product Base Margin     0.819672
# Country                 0.000000
# Region                  0.000000
# State or Province       0.000000
# City                    0.000000
# Postal Code             0.000000
# Order Date              0.000000
# Ship Date               0.000000
# Profit                  0.000000
# Quantity ordered new    0.000000
# Sales                   0.000000
# Order ID                0.000000
# dtype: float64

# %%
df.notnull().sum()
# Out:
# Row ID                  1952
# Order Priority          1952
# Discount                1952
# Unit Price              1952
# Shipping Cost           1952
# Customer ID             1952
# Customer Name           1952
# Ship Mode               1952
# Customer Segment        1952
# Product Category        1952
# Product Sub-Category    1952
# Product Container       1952
# Product Name            1952
# Product Base Margin     1936
# Country                 1952
# Region                  1952
# State or Province       1952
# City                    1952
# Postal Code             1952
# Order Date              1952
# Ship Date               1952
# Profit                  1952
# Quantity ordered new    1952
# Sales                   1952
# Order ID                1952
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()
